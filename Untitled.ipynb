# %%
def get_age(name, names, ages):
    name_index = names.index(name)
    return ages[name_index]
get_age("Milhouse", names, ages)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2     name_index = names.index(name)
#       3     return ages[name_index]
# ----> 4 get_age("Milhouse", names, ages)
#
# NameError: name 'names' is not defined
