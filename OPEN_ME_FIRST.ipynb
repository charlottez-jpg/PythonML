# %% [markdown]
# # Let's set up your envrionment

# %% [markdown]
# ### Import necessary libraries
# *(click the *play* button in the toolbar above to execute a cell)*

# %%
#!pip install ipywidgets tqdm

# %%
import json
import os
import shutil
import datetime
import pandas as pd

import ipywidgets as widgets

# %% [markdown]
# ### 1. Which section are you in?

# %%
student_section = widgets.Dropdown(
    options=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'],
    value='Tuesday',
    description='Section:',
    disabled=False,
)
student_section
# Out:
# Dropdown(description='Section:', index=1, options=('Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Sa…

# %%
student_section.value = "Tuesday"

# %%
student_section.value
# Out:
# 'Tuesday'

# %% [markdown]
# ### 2. What is your name?

# %%
student_name = "Charlotte Zhang"

# %% [markdown]
# ### 3. Set up postcell

# %%
#class_name     = "python_for_datascience"
class_name     = "python_for_mlengineering"
#class_name     = "python_for_financial_datascience"

class_time_period  = "2026_january"

# %%
import os
print(os.getcwd())
# Out:
# /Users/charlottetheghost/PythonML

# %%
import os
print(os.listdir('/Users/charlottetheghost/PythonML'))
# Out:
# ['postcell.log', 'lectures-main', 'postcell.conf.bak', '.ipynb_checkpoints']

# %%
# Out:
# ['output (2).png', 'Customer Segmentation for Personalized Promotions.pptx', 'ISLRv1_Ebook (1).pdf', 'Copilot_20251006_102350.png', '20220610-statements-8997-.pdf', 'Issuing Post Name.pdf', 'BDCC_A2_Commands.pdf', 'BDCC_A9.pdf', 'U-3 _Outline (1).docx', 'text-D2CBAEE17984-1.txt', 'Week_6_2025_Autumn.pptx', 'Segmentation_QA_Document.docx', 'googlechrome.dmg', 'BDCC_A2.html', 'cropped-WechatIMG285.jpg', '[Merged] financial cover sheet.pdf', 'BDP_Class_07.1_Colab_LinearModel_v8.ipynb', 'Project Update3 (7).docx', '.Rhistory', 'Forecasting_U-3.pdf', 'BDCC_A4_Output.pdf', 'assignment2 (1).pdf', 'offense_summary.txt', 'pass.pkpass', 'Project Update2 (1).pdf', 'ADSP31014_Assignment_4 (1).docx', 'All_documents_CS_1744200468303.pdf', 'Visual Studio Code.app', 'All_documents_CS_1738803696870.pdf', 'Project Report (1).pdf', 'WiscLottery.csv', 'JUEYUN ZHANG BIO.pdf', 'Verizon_Presentation_FinalDeck_WithAgenda.pptx', 'BDCC_Final_Project (2).pdf', 'IMG_7604.heic', 'BDCC_A8.pdf', 'Week_6_2025_Autumn (3).pptx', 'BDCC_A8 (1).pdf', 'hw1-1.docx', 'Dockerfile.txt', 'All_documents_CS_1744200339539.pdf', 'Week_6_2025_Autumn (1).pptx', 'MHS_PUF_Documentation2022 (8).docx', 'BDCC_A5.ipynb', 'Tableau note.docx', 'Vaccine History Transferred from a Written Record.pdf.zip', 'ADSP31014_Assignment_4.docx', 'Student_Survey_Responses.xlsx', 'McDonaldsCaseStudy-CheatSheet (1) (1).ipynb', 'RStudio-2023.09.0-463.dmg', 'BaiduNetdisk_mac_4.26.0_x64.dmg', 'AzureML_02_Private_Container_v5 (1).ipynb', 'McDonald EDA.pdf', 'GENBUS656HW6.html', 'ADSP31014_Assignment_4 (3).docx', 'Syllabus_GB656_Spring2024.pdf', 'Zhang, Jueyun report.pdf', 'Charlotte_Zhang_Cover_Letter (1).docx', 'hw3', 'Charlotte_Zhang_DS_Resume_ModerateSpacing_WithDividers_FINAL.pdf', 'Backup_Slides_AutoGenerated.pptx', 'Project Update3 (5).docx', 'GCP Dataproc Basic.pdf', 'file (7).pdf', '2023 Munich Cup - Brochure.pdf', 'assignment2.html', 'Week 1 course notes.pdf', 'Verizon_Presentation_Styled_DarkNavy.pptx', 'ADSP31014_Assignment_2.py', 'Act Sci 654 Project Update 2 (3).Rmd', 'Final Project Written Report Outline (1).docx', 'Week 3 Treasury and Mortgage Rates.py', 'Municipal_Court_Caseload_Information.zip', 'ctyfactbook2023.xlsx', 'AE2FAAF8-36A7-4178-ABF6-DE170C90E9E3-list.pdf', 'BDCC_Final_Project.pdf', 'Charlotte_Zhang_DS_Internship_UChicagoStyle.pdf', 'Scanned Documents.pdf', 'nosqlbooster4mongo-10.0.7.dmg', 'art history final.docx', 'hw1.docx', 'STAT_A1.ipynb', 'financials.pdf', 'Segmentation_QA_Document (1).docx', 'ADSP31014_Assignment_4 (1) (1).docx', 'Act Sci 654 Project Update 2 (2).Rmd', 'Project Update3 (1).docx', '.class_2_data_merged.txt.crc', 'AzureML_02_Private_Container_v5.ipynb', 'Class 8 Docker turorial v17.sh', "McDonald's_Presentation_Organized.pptx", 'puf.xls', '.DS_Store', 'All_documents_CS_1756656604150.pdf', 'file (6).pdf', 'Hive Scripts v21 (1).sql', 'U-3_OLS.ipynb', 'Week 3 PSI Sensitivity (1).r', 'Assignment9_Mina.ipynb', 'final.html', 'RStudio-2023.12.0-369.dmg', 'WiscNursingHome (1).csv', 'Week_6_2025_Autumn (5).pptx', 'Missingness.Rmd', 'ICPSR_38925', 'charlottez_notebook1.ipynb', 'SponsorLetterTemplate (1).doc', '2018parthenon%20day%201.2.pptx', 'rfm_log_combined.jpeg', 'Zoom (1).pkg', 'MyMEPS (2).csv', 'Personalized Promotions for High-Value Customers (Video).pptx', 'cornell_sop.pdf', 'charlottez_notebook3.ipynb', 'adsp37021_lec1_screen.pdf', 'Jueyun Zhang (1).pdf', 'Project Update2.pdf', 'schaffner_walltext.pdf', 'ADSP 31016 High 5_CZ.docx', 'A_Global_History_of_Architecture_----_(1200_ce)-1.pdf', 'Week_6_2025_Autumn (7).pptx', 'STAT_A3.py', 'WiscNursingHome.csv', '1983E9CB-B07C-4C92-BBFE-34AD820F146C-list.pdf', 'pass0.pkpass', 'Premium concept review.pptx', 'McD ADB1-1 (1).twbx', 'i20-2025.pdf', 'puf2022 (6).xls', 'Zhang, Jueyun report (1).pdf', 'Charlotte_Zhang_DS_Resume_ExactOnePage (1).pdf', '.localized', 'charlottez_notebook2 (2).ipynb', 'STAT_A3.ipynb', '~$arlotte_Zhang_Cover_Letter.docx', 'Forecasting_U-3.pptx', 'Project Update3 (3).docx', 'Standard Ultimate ...

# %%
if not os.path.isfile('postcell.conf'):
    shutil.copyfile('postcell.conf.bak', 'postcell.conf')

#Open config file
with open('postcell.conf', 'rt') as conf:
    parsedj = json.load(conf)
    #print(parsedj['student_id'])
    #print(parsedj['class_id'])
    
#Set student name
parsedj['student_id'] = student_name.strip().replace(' ', '_')

#Set class name
class_id = f"{class_time_period}_{student_section.value.lower()}_{class_name}"
parsedj['class_id'] = class_id

#Write config file
#TODO: change should_send_to_server to true, set default to be false in .bak file
with open('postcell.conf', 'wt') as conf:
    json.dump(parsedj, conf, indent=4, sort_keys=True)
    
# Confirm your config
with open('postcell.conf', 'rt') as conf:
    parsedj = json.load(conf)
    print(parsedj['student_id'])
    print(parsedj['class_id'])
# Out:
# Charlotte_Zhang
# 2026_january_tuesday_python_for_mlengineering

# %% [markdown]
# ### 4. Install the postcell magic command

# %%
# !pip install postcell -U --quiet

# %%
# %reload_ext postcell
# %postcell register
# Out:
# PostCell loaded
# Loading config file from /Users/charlottetheghost/PythonML/postcell.conf
# Registered user Charlotte_Zhang at https://postcell.io/post_cell

# %%
# %%postcell OPEN_ME_FIRST_HELLO
# "Hello"
# Out:
# Cell posted for evaluation
# 'Hello'

# %%
# %%postcell OPEN_ME_FIRST_EXPERIENCE
# "BA"
# Out:
# Cell posted for evaluation
# 'BA'

# %% [markdown]
# ### Fun test, how fast is your machine?

# %%
# %%timeit
sum(range(1_000_000))
# Out:
# 9.98 ms ± 154 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### Paste the numeric value from the previous cell, along with a general description of you machine, on the next line

# %%
# %%postcell OPEN_ME_FIRST_MACHINE_PERFORMANCE
# "7.97 ms"
# Out:
# Cell posted for evaluation
# '7.97 ms'

# %% [markdown]
# ### 5. Install other packages
# Since this is an introductory course and we are installing these packages to bootstrap the class.
#
# In later lectures or classes, we will learn that the proper way to do this is to:
# 1. Create a separate environment
# 2. Install packages in that environment, preferrably via a reporoducible  list, such as requirements.txt or env.yaml

# %% [markdown]
# General tools

# %%
# !pip install ipywidgets tqdm
# Out:
# Requirement already satisfied: ipywidgets in /opt/anaconda3/lib/python3.13/site-packages (8.1.5)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (4.67.1)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.13/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/lib/python3.13/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)

# %% [markdown]
# Visualization tools

# %%
# !pip install seaborn bokeh "altair[all]"
# Out:
# Requirement already satisfied: seaborn in /opt/anaconda3/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: bokeh in /opt/anaconda3/lib/python3.13/site-packages (3.6.2)
# Requirement already satisfied: altair[all] in /opt/anaconda3/lib/python3.13/site-packages (5.5.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/anaconda3/lib/python3.13/site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: pandas>=1.2 in /opt/anaconda3/lib/python3.13/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/anaconda3/lib/python3.13/site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: Jinja2>=2.9 in /opt/anaconda3/lib/python3.13/site-packages (from bokeh) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in /opt/anaconda3/lib/python3.13/site-packages (from bokeh) (1.3.1)
# Requirement already satisfied: packaging>=16.8 in /opt/anaconda3/lib/python3.13/site-packages (from bokeh) (24.2)
# Requirement already satisfied: pillow>=7.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from bokeh) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in /opt/anaconda3/lib/python3.13/site-packages (from bokeh) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /opt/anaconda3/lib/python3.13/site-packages (from bokeh) (6.5.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in /opt/anaconda3/lib/python3.13/site-packages (from bokeh) (2022.9.0)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/lib/python3.13/site-packages (from altair[all]) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /opt/anaconda3/lib/python3.13/site-packages (from altair[all]) (1.31.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from altair[all]) (4.12.2)
# Collecting altair-tiles>=0.3.0 (from altair[all])
#   Downloading altair_tiles-0.4.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting anywidget>=0.9.0 (from altair[all])
#   Downloading anywidget-0.9.21-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: pyarrow>=11 in /opt/anaconda3/lib/python3.13/site-packages (from altair[all]) (19.0.0)
# Collecting vega-datasets>=0.9.0 (from altair[all])
#   Downloading vega_datasets-0.9.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting vegafusion>=1.6.6 (from vegafusion[embed]>=1.6.6; extra == "all"->altair[all])
#   Downloading vegafusion-2.0.3-cp39-abi3-macosx_11_0_arm64.whl.metadata (1.1 kB)
# Collecting vl-convert-python>=1.7.0 (from altair[all])
#   Downloading vl_convert_python-1.9.0-cp37-abi3-macosx_11_0_arm64.whl.metadata (339 bytes)
# Collecting mercantile (from altair-tiles>=0.3.0->altair[all])
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: ipywidgets>=7.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from anywidget>=0.9.0->altair[all]) (8.1.5)
# Collecting psygnal>=0.8.1 (from anywidget>=0.9.0->altair[all])
#   Downloading psygnal-0.15.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.1 kB)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (3.0.13)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (2.19.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (4.8.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.13/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/lib/python3.13/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from Jinja2>=2.9->bokeh) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair[all]) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair[all]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair[all]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair[all]) (0.22.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Collecting arro3-core (from vegafusion>=1.6.6->vegafusion[embed]>=1.6.6; extra == "all"->altair[all])
#   Downloading arro3_core-0.6.5-cp311-abi3-macosx_11_0_arm64.whl.metadata (363 bytes)
# Collecting narwhals>=1.14.2 (from altair[all])
#   Downloading narwhals-2.15.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: click>=3.0 in /opt/anaconda3/lib/python3.13/site-packages (from mercantile->altair-tiles>=0.3.0->altair[all]) (8.1.8)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.2.2)
# Downloading altair_tiles-0.4.0-py3-none-any.whl (9.1 kB)
# Downloading anywidget-0.9.21-py3-none-any.whl (231 kB)
# Downloading psygnal-0.15.1-cp313-cp313-macosx_11_0_arm64.whl (574 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 574.8/574.8 kB 14.0 MB/s eta 0:00:00
# Downloading vega_datasets-0.9.0-py3-none-any.whl (210 kB)
# Downloading vegafusion-2.0.3-cp39-abi3-macosx_11_0_arm64.whl (20.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 41.8 MB/s eta 0:00:0031m44.3 MB/s eta 0:00:01
# Downloading narwhals-2.15.0-py3-none-any.whl (432 kB)
# Downloading vl_convert_python-1.9.0-cp37-abi3-macosx_11_0_arm64.whl (29.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 39.1 MB/s eta 0:00:0031m41.2 MB/s eta 0:00:01
# Downloading arro3_core-0.6.5-cp311-abi3-macosx_11_0_arm64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 36.4 MB/s eta 0:00:00
# Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: vl-convert-python, psygnal, narwhals, mercantile, arro3-core, vegafusion, vega-datasets, anywidget, altair-tiles
#   Attempting uninstall: narwhals━━━━━━━━━━━━━━━━━━━━━━ 0/9 [vl-convert-python]
#     Found existing installation: narwhals 1.31.0━━ 0/9 [vl-convert-python]
#     Uninstalling narwhals-1.31.0:━━━━━━━━━━━━━━━━━ 0/9 [vl-convert-python]
#       Successfully uninstalled narwhals-1.31.0;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/9 [narwhals]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [altair-tiles]0m 5/9 [vegafusion]hals]
# Successfully installed altair-tiles-0.4.0 anywidget-0.9.21 arro3-core-0.6.5 mercantile-1.2.1 narwhals-2.15.0 psygnal-0.15.1 vega-datasets-0.9.0 vegafusion-2.0.3 vl-convert-python-1.9.0

# %% [markdown]
# Code quality tools

# %%
# !pip install pylint pytest mypy ruff black
# Out:
# Requirement already satisfied: pylint in /opt/anaconda3/lib/python3.13/site-packages (3.3.5)
# Requirement already satisfied: pytest in /opt/anaconda3/lib/python3.13/site-packages (8.3.4)
# Requirement already satisfied: mypy in /opt/anaconda3/lib/python3.13/site-packages (1.14.1)
# Collecting ruff
#   Downloading ruff-0.14.10-py3-none-macosx_11_0_arm64.whl.metadata (26 kB)
# Requirement already satisfied: black in /opt/anaconda3/lib/python3.13/site-packages (24.10.0)
# Requirement already satisfied: dill>=0.3.6 in /opt/anaconda3/lib/python3.13/site-packages (from pylint) (0.3.8)
# Requirement already satisfied: platformdirs>=2.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from pylint) (4.3.7)
# Requirement already satisfied: astroid<=3.4.0-dev0,>=3.3.8 in /opt/anaconda3/lib/python3.13/site-packages (from pylint) (3.3.8)
# Requirement already satisfied: isort!=5.13.0,<7,>=4.2.5 in /opt/anaconda3/lib/python3.13/site-packages (from pylint) (6.0.1)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /opt/anaconda3/lib/python3.13/site-packages (from pylint) (0.7.0)
# Requirement already satisfied: tomlkit>=0.10.1 in /opt/anaconda3/lib/python3.13/site-packages (from pylint) (0.13.2)
# Requirement already satisfied: iniconfig in /opt/anaconda3/lib/python3.13/site-packages (from pytest) (1.1.1)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from pytest) (24.2)
# Requirement already satisfied: pluggy<2,>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from pytest) (1.5.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from mypy) (4.12.2)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from mypy) (1.0.0)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from black) (8.1.8)
# Requirement already satisfied: pathspec>=0.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from black) (0.10.3)
# Downloading ruff-0.14.10-py3-none-macosx_11_0_arm64.whl (12.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 34.7 MB/s eta 0:00:00MB/s eta 0:00:01
# Installing collected packages: ruff
# Successfully installed ruff-0.14.10

# %% [markdown]
# Additional packages

# %%
# !pip install "fastapi[standard]"
# Out:
# Collecting fastapi[standard]
#   Downloading fastapi-0.128.0-py3-none-any.whl.metadata (30 kB)
# Collecting starlette<0.51.0,>=0.40.0 (from fastapi[standard])
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: pydantic>=2.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastapi[standard]) (2.10.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastapi[standard]) (4.12.2)
# Collecting annotated-doc>=0.0.2 (from fastapi[standard])
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting fastapi-cli>=0.0.8 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading fastapi_cli-0.0.20-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastapi[standard]) (0.28.1)
# Requirement already satisfied: jinja2>=3.1.5 in /opt/anaconda3/lib/python3.13/site-packages (from fastapi[standard]) (3.1.6)
# Collecting python-multipart>=0.0.18 (from fastapi[standard])
#   Downloading python_multipart-0.0.21-py3-none-any.whl.metadata (1.8 kB)
# Collecting email-validator>=2.0.0 (from fastapi[standard])
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Collecting uvicorn>=0.12.0 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading uvicorn-0.40.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: pydantic-settings>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastapi[standard]) (2.6.1)
# Collecting pydantic-extra-types>=2.0.0 (from fastapi[standard])
#   Downloading pydantic_extra_types-2.11.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.23.0->fastapi[standard]) (4.7.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.23.0->fastapi[standard]) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.23.0->fastapi[standard]) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.23.0->fastapi[standard]) (3.7)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->fastapi[standard]) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.13/site-packages (from anyio->httpx<1.0.0,>=0.23.0->fastapi[standard]) (1.3.0)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->fastapi[standard])
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting typer>=0.15.1 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading typer-0.21.1-py3-none-any.whl.metadata (16 kB)
# Collecting rich-toolkit>=0.14.8 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading rich_toolkit-0.17.1-py3-none-any.whl.metadata (1.0 kB)
# Collecting fastapi-cloud-cli>=0.1.1 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading fastapi_cloud_cli-0.8.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting rignore>=0.5.1 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading rignore-0.7.6-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting sentry-sdk>=2.20.0 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading sentry_sdk-2.48.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting fastar>=0.8.0 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading fastar-0.8.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2>=3.1.5->fastapi[standard]) (3.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=2.7.0->fastapi[standard]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=2.7.0->fastapi[standard]) (2.27.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic-settings>=2.0.0->fastapi[standard]) (1.1.0)
# Requirement already satisfied: click>=8.1.7 in /opt/anaconda3/lib/python3.13/site-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (8.1.8)
# Requirement already satisfied: rich>=13.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (0.1.0)
# Requirement already satisfied: urllib3>=1.26.11 in /opt/anaconda3/lib/python3.13/site-packages (from sentry-sdk>=2.20.0->fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (2.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from typer>=0.15.1->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (1.5.0)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading httptools-0.7.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.13/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]) (6.0.2)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading uvloop-0.22.1-cp313-cp313-macosx_10_13_universal2.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading watchfiles-1.1.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading websockets-15.0.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Downloading fastapi-0.128.0-py3-none-any.whl (103 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading email_validator-2.3.0-py3-none-any.whl (35 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
# Downloading fastapi_cli-0.0.20-py3-none-any.whl (12 kB)
# Downloading fastapi_cloud_cli-0.8.0-py3-none-any.whl (22 kB)
# Downloading fastar-0.8.0-cp313-cp313-macosx_11_0_arm64.whl (628 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 629.0/629.0 kB 32.7 MB/s eta 0:00:00
# Downloading pydantic_extra_types-2.11.0-py3-none-any.whl (74 kB)
# Downloading python_multipart-0.0.21-py3-none-any.whl (24 kB)
# Downloading rich_toolkit-0.17.1-py3-none-any.whl (31 kB)
# Downloading rignore-0.7.6-cp313-cp313-macosx_11_0_arm64.whl (820 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 820.1/820.1 kB 31.8 MB/s eta 0:00:00
# Downloading sentry_sdk-2.48.0-py2.py3-none-any.whl (414 kB)
# Downloading typer-0.21.1-py3-none-any.whl (47 kB)
# Downloading uvicorn-0.40.0-py3-none-any.whl (68 kB)
# Downloading httptools-0.7.1-cp313-cp313-macosx_11_0_arm64.whl (108 kB)
# Downloading uvloop-0.22.1-cp313-cp313-macosx_10_13_universal2.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.0 MB/s eta 0:00:00
# Downloading watchfiles-1.1.1-cp313-cp313-macosx_11_0_arm64.whl (391 kB)
# Downloading websockets-15.0.1-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Installing collected packages: websockets, uvloop, uvicorn, sentry-sdk, rignore, python-multipart, httptools, fastar, dnspython, annotated-doc, watchfiles, starlette, email-validator, typer, rich-toolkit, pydantic-extra-types, fastapi, fastapi-cloud-cli, fastapi-cli
#   Attempting uninstall: typer━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━ 11/19 [starlette]ptools]
#     Found existing installation: typer 0.9.0╺━━━━━━━━━━━━━━━━ 11/19 [starlette]
#     Uninstalling typer-0.9.0:━━━━━━━━━━━╺━━━━━━━━━━━━━━━━ 11/19 [starlette]
#       Successfully uninstalled typer-0.9.00m╺━━━━━━━━━━━━━━━━ 11/19 [starlette]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19/19 [fastapi-cli]━━━━ 16/19 [fastapi]
# Successfully installed annotated-doc-0.0.4 dnspython-2.8.0 email-validator-2.3.0 fastapi-0.128.0 fastapi-cli-0.0.20 fastapi-cloud-cli-0.8.0 fastar-0.8.0 httptools-0.7.1 pydantic-extra-types-2.11.0 python-multipart-0.0.21 rich-toolkit-0.17.1 rignore-0.7.6 sentry-sdk-2.48.0 starlette-0.50.0 typer-0.21.1 uvicorn-0.40.0 uvloop-0.22.1 watchfiles-1.1.1 websockets-15.0.1

# %%
# Add kernel

#conda activate py310
#python -m ipykernel install --user --name="py310"
